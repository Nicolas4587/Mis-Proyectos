# %%
#clase 2
## Estruturas de seleccion
# Out:
# 10

# %% [markdown]
# #clase 2
# ## Estruturas de seleccion
#
# 1. estructuras simples si(if)
# 2. estructuras si ( if/else)
# 3. estructuras si multiples(if/elif/else)

# %% [markdown]
# 1. estructura simple si
# ![estructura_seleccion_simple.png](data:image/png;base64,...)

# %%
x=int(input ("ingresar un numero "))
if x>=0:
 print(x," El numero de positivo")
# Out:
# ingresar un numero 545
# 545  El numero de positivo

# %% [markdown]
# ##2. Estructura si/sino
# ![imagen02.png](data:image/png;base64,...)

# %%
if x>=0:
 print(x,"es un numero es positivo")
else: 
   print(f"{x}es un numero es psotivo")
# Out:
# 545 es un numero es positivo

# %% [markdown]
# ##3. estructura si multiples if / elif/ else
# ![imagen06.png](data:image/png;base64,...)

# %%
## un igual es asignacion
## dos igual es comparacion
x=int(input("ingrese un numero"))
if x>0:
 print(x,"es un numero es positivo") # impresion de lista
elif x==0:
  print(str(x)+"es cero") #concatenando
else: 
  print(f" {x} es un numero es positivo ")#imprimiendo una funcion
# Out:
# ingrese un numero0
# 0es cero
