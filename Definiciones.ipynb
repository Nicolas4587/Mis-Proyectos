# %% [markdown]
# ##while:
# La palabra clave while se utiliza para crear un bucle while.
#
# Un ciclo while continuará hasta que la declaración sea falsa.
#
# ![Captura.PNG](data:image/png;base64,...)

# %% [markdown]
# ##try:
# La palabra clave try se usa en try...except blocks. Define un bloque de prueba de código si contiene algún error.
#
# Puede definir diferentes bloques para diferentes tipos de error y bloques para ejecutar si nada salió mal, vea los ejemplos a continuación.
# ![Captura.PNG1.PNG](data:image/png;base64,...)

# %% [markdown]
# ##True:
# La palabra clave True es un valor booleano y el resultado de una operación de comparación.
#
# La palabra clave True es igual a 1 (False es igual a 0).
# ![Captura.PNG2.PNG](data:image/png;base64,...)

# %% [markdown]
# ##return:
# La palabra clave de retorno es para salir de una función y devolver un valor.
#
# ![Captura.PNG4.PNG](data:image/png;base64,...)

# %% [markdown]
# ##raise:
# La palabra clave raise se utiliza para generar una excepción.
#
# Puede definir qué tipo de error generar y el texto para imprimir al usuario.
# ![Captura.PNG5.PNG](data:image/png;base64,...)

# %% [markdown]
# ##pass:
# La declaración de paso se utiliza como marcador de posición para el código futuro.
#
# Cuando se ejecuta la declaración de paso, no sucede nada, pero evita obtener un error cuando no se permite el código vacío.
# ![Captura.PNG6.PNG](data:image/png;base64,...)

# %% [markdown]
# ##or:
# La palabra clave o es un operador lógico.
#
# Los operadores lógicos se utilizan para combinar sentencias condicionales.
# ![Captura.PNG7.PNG](data:image/png;base64,...)

# %% [markdown]
# ##not:
# La palabra clave not es un operador lógico.
#
# El valor devuelto será Verdadero si las declaraciones no son Verdaderas, de lo contrario, devolverá Falso.
# ![Captura.PNG8.PNG](data:image/png;base64,...)

# %% [markdown]
# ##nonlocal:
# La palabra clave nonlocal se usa para trabajar con variables dentro de funciones anidadas, donde la variable no debe pertenecer a la función interna.
#
# Utilice la palabra clave nonlocal para declarar que la variable no es local.
#
# ![Captura.PNG9.PNG](data:image/png;base64,...)

# %% [markdown]
# ##None:
# La palabra clave Ninguno se utiliza para definir un valor nulo o ningún valor.
#
# ![Captura.PNG10.PNG](data:image/png;base64,...)

# %% [markdown]
# ##lambda:
# La palabra clave lambda se usa para crear pequeñas funciones anónimas.
#
# Una función lambda puede tomar cualquier cantidad de argumentos, pero solo puede tener una expresión.
#
# ![Captura.PNG11.PNG](data:image/png;base64,...)

# %% [markdown]
# ##is:
# La palabra clave is se usa para probar si dos variables se refieren al mismo objeto.
#
# ![Captura.PNG12.PNG](data:image/png;base64,...)

# %% [markdown]
# ##in:
# La palabra clave in tiene dos propósitos:
#
# La palabra clave in se utiliza para verificar si un valor está presente en una secuencia (lista, rango, cadena, etc.).
#
# ![Captura.PNG13.PNG](data:image/png;base64,...)

# %% [markdown]
# ##import:
# La palabra clave de importación se utiliza para importar módulos.
#
# ![Captura.PNG14.PNG](data:image/png;base64,...)

# %% [markdown]
# ##if:
# La palabra clave if se usa para crear declaraciones condicionales (si declaraciones) y le permite ejecutar un bloque de código solo si una condición es verdadera.
#
# ![Captura.PNG15.PNG](data:image/png;base64,...)

# %% [markdown]
# ##global:
# La palabra clave global se utiliza para crear variables globales desde un ámbito no global, p. dentro de una función.
#
# ![Captura.PNG16.PNG](data:image/png;base64,...)

# %% [markdown]
# ##from:
# The from keyword is used to import only a specified section from a module.
#
# ![Captura.PNG17.PNG](data:image/png;base64,...)

# %% [markdown]
# ##for:
# La palabra clave for se utiliza para crear un bucle for.
#
# ![Captura.PNG18.PNG](data:image/png;base64,...)

# %% [markdown]
# ##finally:
# La palabra clave finalmente se usa en try...except blocks. Define un bloque de código para ejecutar cuando el bloque try...except...else es definitivo.
#
# El bloque "finally" se ejecutará sin importar si el bloque "try" genera un error o no.
#
# ![Captura.PNG19.PNG](data:image/png;base64,...)

# %% [markdown]
# ##False:
# La palabra clave False es un valor booleano y el resultado de una operación de comparación.
#
# La palabra clave Falso es lo mismo que 0 (Verdadero es lo mismo que 1).
#
# ![Captura.PNG20.PNG](data:image/png;base64,...)

# %% [markdown]
# ##except:
# La palabra clave excepto se usa en los bloques try...except. Define un bloque de código para ejecutar si el bloque de prueba genera un error.
#
# ![Captura.PNG21.PNG](data:image/png;base64,...)

# %% [markdown]
# ##else:
# La palabra clave else se usa en declaraciones condicionales (si declaraciones) y decide qué hacer si la condición es falsa.
#
# ![Captura.PNG22.PNG](data:image/png;base64,...)

# %% [markdown]
# ##elif:
# La palabra clave elif se usa en sentencias condicionales (si sentencias), y es la abreviatura de else if.
#
# ![23.PNG](data:image/png;base64,...)

# %% [markdown]
# ##del:
# La palabra clave del se utiliza para eliminar objetos. En Python, todo es un objeto, por lo que la palabra clave del también se puede usar para eliminar variables, listas o partes de una lista, etc.
#
# ![Captura.PNG54.PNG](data:image/png;base64,...)

# %% [markdown]
# ##def:
# La palabra clave def se usa para crear (o definir) una función.
#
# ![Captura.PNG55.PNG](data:image/png;base64,...)

# %% [markdown]
# ##continue:
# La palabra clave continue se usa para finalizar la iteración actual en un bucle for (o un bucle while) y continúa con la siguiente iteración.
#
# ![Captura.PNG56.PNG](data:image/png;base64,...)

# %% [markdown]
# ##class:
# La palabra clave class se utiliza para crear una clase.
#
# ![Captura.PNG57.PNG](data:image/png;base64,...)

# %% [markdown]
# ##break:
# La palabra clave break se utiliza para dividir un bucle for o un bucle while.
#
# ![Captura.PNG58.PNG](data:image/png;base64,...)

# %% [markdown]
# ##assert:
# La palabra clave assert se usa al depurar código.
#
# La palabra clave assert le permite probar si una condición en su código devuelve True, si no, el programa generará un AssertionError.
#
# ![Captura.PNG59.PNG](data:image/png;base64,...)

# %% [markdown]
# ##as:
# La palabra clave as se utiliza para crear un alias.
#
# ![Captura.PNG60.PNG](data:image/png;base64,...)

# %% [markdown]
# ##and:
# La palabra clave and es un operador lógico.
#
# Los operadores lógicos se utilizan para combinar sentencias condicionales.
#
# ![Captura.PNG61.PNG](data:image/png;base64,...)
